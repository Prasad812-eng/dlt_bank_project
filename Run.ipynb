# %%
# %sql
select * from dlt_bank_project.dlt_bank_schema.landing_customers_incremental

# %%
# %sql
select * from dlt_bank_project.dlt_bank_schema.landing_accounts_transactions

# %%
# %sql
select * from dlt_bank_project.dlt_bank_schema.bronze_customer_ingestion_cleaned where customer_id in(82,99,134,179,186)

# %%
# %sql
select * from dlt_bank_project.dlt_bank_schema.bronze_accounts_cleaned

# %%
# %sql
select * from dlt_bank_project.dlt_bank_schema.silver_accounts_transformed

# %%
# %sql
select * from dlt_bank_project.dlt_bank_schema.silver_customer_transformed_scd1

# %%
# %sql
select * from dlt_bank_project.dlt_bank_schema.gold_customer_account_transaction_mv

# %%
# %sql
select * from dlt_bank_project.dlt_bank_schema.gold_cust_acc_trans_agg
